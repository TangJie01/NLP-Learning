# %%
#python-basics-print

print(1)
print("I'm learning NLP.")
print('I\'m learning NLP.')
print("apple"+"car")
print("apple"+"6"+'6'+str(6))
print(1+2)
print(int('1')+2)
print(float('1.2')+2)
print("1.2+2=",1.2+2,sep='')
print(f"1.2+2={1.2+2}")
1+1
# Out:
# 1
# I'm learning NLP.
# I'm learning NLP.
# applecar
# apple666
# 3
# 3
# 3.2
# 1.2+2=3.2
# 1.2+2=3.2
# 2

# %%
1+1
# Out:
# 2

# %%
1-1
# Out:
# 0

# %%
2*1
# Out:
# 2

# %%
#2的三次方，2^3
2**3
# Out:
# 8

# %%
#取余
8%3
# Out:
# 2

# %%
#取整
9//4
# Out:
# 2

# %%
#python-basic-veriable

apple = 10
apple_agg = 10 + 2
a,b,c = 1,2,3
d = b*10
print(apple)
print(apple_agg)
print(a,b,c,d)
# Out:
# 10
# 12
# 1 2 3 20
